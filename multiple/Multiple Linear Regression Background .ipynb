# %% [markdown]
# ```bash
# Multiple Linear Regression
# ```

# %% [markdown]
# ```bash
# MULTIPLE LINEAR REGRESSION:
# predict the value of the dependent variable (S&P 500, Dow Jones, Nasdaq) based on multiple independent variables (consumer price index, unemployment rate, gross domestic product growth, m2 money supply, and federal funds rate).
# ```

# %% [markdown]
# ```bash
# In general the mathematical Equation:
# ```

# %% [markdown]
# ![Screen Shot 2025-04-14 at 5.23.09 PM.png](attachment:d5e71718-8dc4-4dbb-b9f3-a5535f39b5e7.png)

# %% [markdown]
# ![Screen Shot 2025-04-14 at 5.23.50 PM.png](attachment:2128a643-13f6-4415-b5ca-f460fd679a1e.png)

# %% [markdown]
# ```bash
# Using Orinary Least Squares (OLS) method MLR finds the best beta values to minimize the sum of squared residuals.
# ```

# %% [markdown]
# ![Screen Shot 2025-04-14 at 5.27.02 PM.png](attachment:421f42c9-9788-487d-a86d-576acd95ee15.png)

# %% [markdown]
# ```bash
# When we use statsmodel to compute the OLS model and use the .fit() argument, it is essentially solving for the beta values that minimize the sum of squared residuals. Using the .predict() argument it is making predictions using the following formula:
# ````

# %% [markdown]
# ![Screen Shot 2025-04-14 at 5.31.13 PM.png](attachment:22e1b154-9d3b-4ff4-a4bc-e6891472492c.png)
