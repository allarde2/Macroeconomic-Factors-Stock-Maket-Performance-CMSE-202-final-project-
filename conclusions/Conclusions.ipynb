# %% [markdown]
# <div style="font-family: 'Times New Roman'; font-size: 20px; color: black;">
#   <p style="text-align: center; font-size: 24px;"><strong>S&P 500 Model Summary</strong></p>
#   <table border="1" class="dataframe">
#     <thead>
#       <tr style="text-align: right;">
#         <th>Model</th>
#         <th>R-squared</th>
#         <th>RMSE</th>
#         <th>Important Variables</th>
#         <th>Interpretation</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>Multiple Linear Regression (Full)</td>
#         <td>0.935</td>
#         <td>717.80</td>
#         <td>↑ CPI (12.93), ↓ Unemployment (-122.51), ↑ GDP (20.23), ↑ M2 (0.11)</td>
#         <td>Real IR and Fed Funds not significant. Unemployment & GDP drive model performance.</td>
#       </tr>
#       <tr>
#         <td>Multiple Linear Regression (Reduced)</td>
#         <td>0.922</td>
#         <td>588.82</td>
#         <td>↓ Unemployment (-133.66), ↑ GDP (14.89), ↑ M2 (0.16)</td>
#         <td>Reduced model improved RMSE. Focused on statistical significance and reduced collinearity.</td>
#       </tr>
#       <tr>
#         <td>Lasso Regression</td>
#         <td>N/A</td>
#         <td>738.24</td>
#         <td>↓ Unemployment, ↑ M2, ↓ CPI (from coefficient outputs)</td>
#         <td>Lasso preserved key variables while controlling for multicollinearity. RMSE increased sightly.</td>
#       </tr>
#       <tr>
#         <td>Time Series Lasso (with differencing)</td>
#         <td>N/A</td>
#         <td>215.23</td>
#         <td>↑ GDP, ↓ Unemployment, ↑ M2</td>
#         <td>Incorporating S&P differencing dramatically improves RMSE. Struggled with sporadic changes.</td>
#       </tr>
#     </tbody>
#   </table>
# </div>

# %% [markdown]
# <div style="font-family: 'Times New Roman'; font-size: 20px; color: black;">
#   <p style="text-align: center; font-size: 24px;"><strong>Dow Jones Model Summary</strong></p>
#   <table border="1" class="dataframe">
#     <thead>
#       <tr style="text-align: right;">
#         <th>Model</th>
#         <th>R-squared</th>
#         <th>RMSE</th>
#         <th>Important Variables</th>
#         <th>Interpretation</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>Multiple Linear Regression (Full)</td>
#         <td>0.958</td>
#         <td>5,969.81</td>
#         <td>↑ CPI (198.23), ↓ Unemployment (-966.60), ↑ GDP (161.26), ↑ M2 (0.56)</td>
#         <td>Real IR and Fed Funds not significant. Strongest R² across all indices. Driven by employment and growth.</td>
#       </tr>
#       <tr>
#         <td>Multiple Linear Regression (Reduced)</td>
#         <td>0.931</td>
#         <td>3,240.48</td>
#         <td>↓ Unemployment (-937.36), ↑ M2 (1.39)</td>
#         <td>Reduced model improved RMSE. Focused on statistical significance and reduced collinearity.</td>
#       </tr>
#       <tr>
#         <td>Lasso Regression</td>
#         <td>N/A</td>
#         <td>6,101.33</td>
#         <td>↓ Unemployment, ↑ M2, ↓ CPI (from coefficient outputs)</td>
#         <td>Over-penalized. RMSE significantly worsened. Still highlights monetary and labor market importance.</td>
#       </tr>
#       <tr>
#         <td>Time Series Lasso (with differencing)</td>
#         <td>N/A</td>
#         <td>1,806.29</td>
#         <td>↑ GDP, ↓ Unemployment, ↑ M2</td>
#         <td>differencing led to large RMSE improvement. Struggled with sporadic changes.</td>
#       </tr>
#     </tbody>
#   </table>
# </div>

# %% [markdown]
# <div style="font-family: 'Times New Roman'; font-size: 20px; color: black;">
#   <p style="text-align: center; font-size: 24px;"><strong>NASDAQ Model Summary</strong></p>
#   <table border="1" class="dataframe">
#     <thead>
#       <tr style="text-align: right;">
#         <th>Model</th>
#         <th>R-squared</th>
#         <th>RMSE</th>
#         <th>Important Variables</th>
#         <th>Interpretation</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>Multiple Linear Regression (Full)</td>
#         <td>0.886</td>
#         <td>2846.64</td>
#         <td>↓ Unemployment (-216.43), ↑ GDP (45.69), ↑ M2 (0.57), ↑ Fed Funds (120.56)</td>
#         <td>CPI and Real IR not significant. Strongest R² across all indices. Driven by employment and rates.</td>
#       </tr>
#       <tr>
#         <td>Multiple Linear Regression (Reduced)</td>
#         <td>0.882</td>
#         <td>3248.11</td>
#         <td>↓ Unemployment (-231.51), ↑ GDP (52.95), ↑ M2 (0.47), ↑ Fed Funds (121.43)</td>
#         <td>Reduced model increased RMSE. Focused on statistical significance.</td>
#       </tr>
#       <tr>
#         <td>Lasso Regression</td>
#         <td>N/A</td>
#         <td>3,158.26</td>
#         <td>↓ Unemployment, ↑ M2, ↑ GDP (from coefficient outputs)</td>
#         <td>Over-penalized. RMSE worsened, but was better than reduced MLR. Highlights growth and monetary importance.</td>
#       </tr>
#       <tr>
#         <td>Time Series Lasso (with differencing)</td>
#         <td>N/A</td>
#         <td>1,102.88</td>
#         <td>↑ GDP, ↓ Unemployment, ↑ M2</td>
#         <td>Differencing led to large RMSE improvement, differenced NASDAQ was an important predictor.</td>
#       </tr>
#     </tbody>
#   </table>
# </div>

# %% [markdown]
# <p style="font-family: 'Times New Roman'; font-size: 18px; color: black; text-align: justify;">
#   Our analysis finds that macroeconomic factors explain a substantial portion of variation in all three major U.S. stock indices over time, with R-squared values as high as 0.958 for the Dow Jones and 0.935 for the S&amp;P 500 using multiple linear regression. Across all models, <strong>Unemployment Rate</strong> and <strong>GDP Growth</strong> consistently emerged as the most influential predictors, while <strong>M2 Money Supply</strong> also showed strong predictive power, particularly in Lasso and Time Series models. Although CPI and Federal Funds Rate occasionally appeared significant, they were less consistently important, and models using differencing significantly improved prediction accuracy by capturing temporal momentum and macroeconomic shocks.
# </p>

# %% [markdown]
# <div style="font-family: 'Times New Roman'; font-size: 18px; text-align: center; width: 100%;">
#   <p><strong>SOURCES</strong></p>
#   <p>Referenced generative AI on April 20th, 2024:</p>
#   <p><em>Prompt 1:</em> Given this in a Jupyter markdown cell, can you format it using HTML?</p>
# </div>
