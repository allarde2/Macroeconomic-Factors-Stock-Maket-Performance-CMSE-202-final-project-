# %% [markdown]
# <div style = "text-align: center; color: black; font-family: Times New Roman;">
#   <strong><h1>TIME-SERIES WITH LASSO BACKGROUND<strong></h1>
# </div>

# %% [markdown]
# <p style="font-family: 'Times New Roman'; font-size: 18px; text-align: center; color: black;">
#   Due to the nature of our dataset being separated by time, we wanted to explore time-series analysis with Lasso. You can extend this further, and use time-series as a forecaster for previous years, using just the interested variable or exogenous variables that would enhance the analysis. For the purpose of our course, we will just be differencing the data, that way we can see how important the previous quarters variable is in predicting the current quarters variable. This style of time series uses a simple version of ARIMA. ARIMA is Autoregressive Integrated Moving Average, and we will be focusing just on the differncing portion.
# </p>

# %% [markdown]
# <p style="font-family: 'Times New Roman'; font-size: 18px; text-align: center; color: black;">
#   To begin, for our dependent variable (S&P 500, Dow Jones, NASDAQ), we created a first difference column using the
#   <strong>.diff()</strong> function built into pandas. The mathematical formula is:
# </p>

# %% [markdown]
# <div style="text-align: center;">
#   <img src="attachment:41ca08f6-c09d-4f2f-b5c2-f8c2d19109d4.png" alt="First Difference Formula" style="max-width: 100%; height: auto;">
# </div>

# %% [markdown]
# <p style="font-family: 'Times New Roman'; font-size: 18px; text-align: center; color: black;">
#   For example, if S&P 500 over four quarters included the values: [100, 105, 125, 135], then after applying first differencing,
#   the new column would be: [NA, 5, 20, 10]. This transformation helps make the data stationary, so that the mean and variance
#   remain consistent over time.
# </p>

# %% [markdown]
# <p style="font-family: 'Times New Roman'; font-size: 18px; text-align: center; color: black;">
#   Then, when preparing our data for LASSO Regression, we included the previous quarter as the independent variable and the current quarter as the dependent variable.
#   We implemented this using the <strong>.iloc</strong> function in pandas. For the previous quarter’s data (t‒1), we used
#   <code style="font-size: 15px;">x = data[independent_variables].iloc[0:-1]</code>, and for the current quarter (t), we used
#   <code style="font-size: 15px;">y = data[dependent_variable].iloc[1:]</code>. We then proceeded with our LASSO regression analysis as normal.
# </p>
