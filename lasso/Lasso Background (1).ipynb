# %% [markdown]
# ```bash
# Lasso Analysis background:
#
# LASSO (Least Absolute Shrinkage and Selection Operator): a linear regression technique that uses L1 regularization, where it adds a penalty term to the loss function, which encourages these coefficients to shrink to zero; therefore, it gets rid of the less important variables.
#
# y: dependent variable (S&P 500, Dow Jones, Nasdaq)
# x: cpi, real interest rate, unemployment rate, gdp growth, m2 money supply, federal fund rate
# yi: actual values
# yi (hat): predicted values from the model
# Bj: coeffiicent weights for x variables
# Lambda: regularization strength, how much weight is added to the penalty term
# 1st term: residual sum of squares, how far the predicted values are from actual values
# 2nd term: L1 penalty, sum of the absolute values of coefficients
#
# s&p500 = B0 + B1 * CPI + B2 * real ir + B3 * unemployment rate + B4 * gdp growth + B5 * M2 money supply t + B6 * federal funds rate + error
# Beta tells you how much the dependent variable changes when one x variable increases by 1, all other x variables constant
# ```

# %% [markdown]
# ![Screen Shot 2025-04-14 at 8.32.35 PM.png](attachment:ae78bb0b-22f8-4cc7-b20c-227591745393.png)
