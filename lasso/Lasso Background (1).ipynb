# %% [markdown]
# <div style = "text-align: center; color: black; font-family: Times New Roman;">
#   <strong><h1>LASSO REGRESSION BACKGROUND<strong></h1>
# </div>

# %% [markdown]
# <p style="font-family: 'Times New Roman'; font-size: 18px; text-align: center; color: black;">
#   For our project, the goal of using Lasso Regression is to branch deeper into our multiple linear regression analysis. LASSO (Least Absolute and Selection Operator) is a linear regression that uses L1 regularization. L1 regularization is where a penalty term to the loss function, which is porportional to the sum of the absolute value of beta values. Lasso is unique because it drives non-important coefficients to zero, and reduces collineraity and overfitting. The General Mathematical Equation is as follows:
# </p>

# %% [markdown]
# ![Screen Shot 2025-04-19 at 8.33.45 PM.png](attachment:bca42180-87aa-4c41-97dc-158d6238ab32.png)

# %% [markdown]
# <p style="font-family: 'Times New Roman'; font-size: 18px; text-align: center; color: black;">
#   The first term of this equation represents the loss function, where OLS reduces the sum of residual squares. Then, lambda & the sum of the absolute value of beta values represents the addition from Multiple Linear Regression. For our project scope, we are interested in the strength of macroeconomic variable coefficients (beta values), and which approach zero at a lower lambda value. In summary, Multiple Linear Regression ~ Lasso regression when lambda is equal to zero.
# </p>
